# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import seaborn as sns
import plotly.express as px
from scipy.stats import skew
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# %%
#import of the data
table1_url = '/content/drive/Shareddrives/Econ paper/ludo/data_file1.csv'
table1 = pd.read_csv(table1_url)
display(table1)
# Out:
#            date        dow  month  year  monthyear  daily_woi  \
# 0     29sep2000     Friday      9  2000        488   0.850000
# 1     30sep2000   Saturday      9  2000        488   0.715333
# 2     01oct2000     Sunday     10  2000        489   0.881793
# 3     02oct2000     Monday     10  2000        489   0.956902
# 4     03oct2000    Tuesday     10  2000        489   0.750000
# ...         ...        ...    ...   ...        ...        ...
# 4069  20nov2011     Sunday     11  2011        622   0.800000
# 4070  21nov2011     Monday     11  2011        622   0.825000
# 4071  22nov2011    Tuesday     11  2011        622   1.058333
# 4072  23nov2011  Wednesday     11  2011        622   0.775000
# 4073  24nov2011   Thursday     11  2011        622   0.616667
#
#       daily_woi_c_med  daily_woi_nc  daily_woi_long  interpolated_news  ...  \
# 0            0.850000      0.850000        1.066667                  0  ...
# ...

# %%
display(table1.iloc[1004:,0:5])
# Out:
#            date        dow  month  year  monthyear
# 1004  30jun2003     Monday      6  2003        521
# 1005  01jul2003    Tuesday      7  2003        522
# 1006  02jul2003  Wednesday      7  2003        522
# 1007  03jul2003   Thursday      7  2003        522
# 1008  04jul2003     Friday      7  2003        522
# ...         ...        ...    ...   ...        ...
# 4069  20nov2011     Sunday     11  2011        622
# 4070  21nov2011     Monday     11  2011        622
# 4071  22nov2011    Tuesday     11  2011        622
# 4072  23nov2011  Wednesday     11  2011        622
# 4073  24nov2011   Thursday     11  2011        622
#
# [3070 rows x 5 columns]

# %%
table_url = '/content/drive/Shareddrives/Econ paper/ludo/tweet.csv'
table = pd.read_csv(table_url)
display(table)
# Out:
#       Unnamed: 0       date  tweet_count
# 0              0  21mar2006            0
# 1              1  22mar2006            0
# 2              2  23mar2006            0
# 3              3  24mar2006            0
# 4              4  25mar2006            0
# ...          ...        ...          ...
# 2107        2107  27dec2011          128
# 2108        2108  28dec2011          111
# 2109        2109  29dec2011           72
# 2110        2110  30dec2011           56
# 2111        2111  31dec2011           25
#
# [2112 rows x 3 columns]

# %%
clean_table = table.copy()
clean_table
# Out:
#       Unnamed: 0       date  tweet_count
# 0              0  21mar2006            0
# 1              1  22mar2006            0
# 2              2  23mar2006            0
# 3              3  24mar2006            0
# 4              4  25mar2006            0
# ...          ...        ...          ...
# 2107        2107  27dec2011          128
# 2108        2108  28dec2011          111
# 2109        2109  29dec2011           72
# 2110        2110  30dec2011           56
# 2111        2111  31dec2011           25
#
# [2112 rows x 3 columns]

# %%
final = clean_table[["date","tweet_count"]]
display(final)
# Out:
#            date  tweet_count
# 0     21mar2006            0
# 1     22mar2006            0
# 2     23mar2006            0
# 3     24mar2006            0
# 4     25mar2006            0
# ...         ...          ...
# 2107  27dec2011          128
# 2108  28dec2011          111
# 2109  29dec2011           72
# 2110  30dec2011           56
# 2111  31dec2011           25
#
# [2112 rows x 2 columns]

# %%
final["ln_tweet_count"] = np.log(final["tweet_count"]+1)
final
# Out:
#            date  tweet_count  ln_tweet_count
# 0     21mar2006            0        0.000000
# 1     22mar2006            0        0.000000
# 2     23mar2006            0        0.000000
# 3     24mar2006            0        0.000000
# 4     25mar2006            0        0.000000
# ...         ...          ...             ...
# 2107  27dec2011          128        4.859812
# 2108  28dec2011          111        4.718499
# 2109  29dec2011           72        4.290459
# 2110  30dec2011           56        4.043051
# 2111  31dec2011           25        3.258097
#
# [2112 rows x 3 columns]

# %%
new_merged = table1.merge(final, on="date", how="left")
new_merged[['tweet_count','ln_tweet_count']] = new_merged[['tweet_count','ln_tweet_count']]
display(new_merged)
# Out:
#            date        dow  month  year  monthyear  daily_woi  \
# 0     29sep2000     Friday      9  2000        488   0.850000
# 1     30sep2000   Saturday      9  2000        488   0.715333
# 2     01oct2000     Sunday     10  2000        489   0.881793
# 3     02oct2000     Monday     10  2000        489   0.956902
# 4     03oct2000    Tuesday     10  2000        489   0.750000
# ...         ...        ...    ...   ...        ...        ...
# 4069  20nov2011     Sunday     11  2011        622   0.800000
# 4070  21nov2011     Monday     11  2011        622   0.825000
# 4071  22nov2011    Tuesday     11  2011        622   1.058333
# 4072  23nov2011  Wednesday     11  2011        622   0.775000
# 4073  24nov2011   Thursday     11  2011        622   0.616667
#
#       daily_woi_c_med  daily_woi_nc  daily_woi_long  interpolated_news  ...  \
# 0            0.850000      0.850000        1.066667                  0  ...
# ...

# %%
new_merged.to_stata("/content/drive/Shareddrives/Econ paper/ludo/data_tweet_new.dta")
